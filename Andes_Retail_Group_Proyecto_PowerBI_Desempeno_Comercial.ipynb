# %% [markdown]
# # 📊 Proyecto: Dashboard de desempeño comercial 2024–2025
# Empresa: **Andes Retail Group**
#
# Este notebook servirá como guía estructurada para el desarrollo del proyecto en Power BI.

# %% [markdown]
# ## 🔹 Paso 1: Conexión y Exploración
#
# - Importar el archivo excel en Power BI Desktop.
# - Revisar tipos de datos.
# - Identificar columnas clave.
# - Explorar estructura general del dataset.

# %% [markdown]
# En esta etapa se importó el archivo Andes_Retail_Group_2024_2025.xlsx en Power BI Desktop y se revisó la estructura general de la tabla.
#
# Se validaron los tipos de datos de cada columna (fechas, numéricos y categóricos) para asegurar su correcta interpretación. También se identificaron las columnas clave del análisis relacionadas con tiempo, cliente, geografía, producto y métricas comerciales (Ingresos, Costo y Unidades Vendidas).

# %% [markdown]
# ## 🔹 Paso 2: Transformación con Power Query
#
# - Cambiar el formato de `Fecha_pedido` a español (Latinoamérica).
# - Corregir los **tipos de datos** de columnas numéricas.
# - Crear una columna condicional `Nivel_Venta` basada en `Ingresos`. Reglas:
#   - Si `Ingresos` es mayor o igual a 1000 → "Venta Alta"
#   - De lo contrario → "Venta Baja"
# - Activar **Vista Perfil de Columna** para validar calidad.
# - Dejar el dataset listo para análisis.

# %% [markdown]
# ## 🔹 Paso 3: Diseño y planificación del Dashboard (antes y durante la construcción)
#
# - Definir qué pregunta responde cada vista (Overview y Detalle).
# - Especificar qué KPIs incluirás y por qué.
# - Explicar qué gráfico usarás para cada pregunta y justifica la elección.
# - Describir la jerarquía visual (qué verá primero el usuario).
# - Indicar cómo distribuirás los elementos en la página.
# - Especificar qué segmentadores usaras

# %% [markdown]
# ### Diseño y planificación
#
# #### Vista Overview - ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025?
# Especifica qué KPIs incluirás y por qué: (3-4 KPIs)
#
# - Ingresos: permite medir el desempeño comercial total del negocio.
# - Costo: ayuda a entender cuánto se invierte para generar las ventas.
# - Ganancia: muestra la rentabilidad real del negocio (Ingresos − Costo).
# - Unidades vendidas: permite analizar el volumen de productos comercializados.
#
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Gráfico de tiempo: Gráfico de línea – Ingresos vs Fecha_Pedido, para visualizar la evolución de los ingresos a lo largo del tiempo y comparar tendencias entre 2024 y 2025.
# - Gráfico comparación geográfica: Gráfico de barras – Ingresos vs País, permite comparar fácilmente el desempeño comercial entre los diferentes países.
# - Gráfico comparación clientes/productos: Gráfico de barras – Ingresos vs Categoría_Producto, para identificar qué categorías generan mayor impacto en el negocio.
#
# Descripción de la jerarquía visual:
# - Título del dashboard en la parte superior.
# - KPIs principales en la parte superior para una lectura rápida del desempeño.
# - Gráfico de evolución temporal en el centro para analizar tendencias.
# - Gráficos comparativos en la parte inferior para identificar diferencias entre países y categorías.
#
# Segmentador(es)
# - Año
#
# #### Vista detalle - ¿Por qué se han caido/subido/mantenido los ingresos?
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# -Gráfico comparación estacional contra ingresos: Gráfico de barras – Ingresos vs Estación, para identificar patrones de venta según temporada.
# - Gráfico comparación segmentos contra ingresos: Gráfico de barras – Ingresos vs Segmento_Cliente, para analizar qué tipo de cliente genera mayor ingreso.
# - Gráfico comparación región contra ingresos: Gráfico de barras – Ingresos vs Región, para detectar diferencias comerciales dentro de cada país.
#
#
# Tabla mostrando 4-6 columnas:
# - Conteo ID_Pedido
# - Conteo único ID_Cliente
# - Ingresos
# - Costo
# - Unidades_Vendidas
#
# Segmentadores (mínimo 2)
# - `Fecha_pedido`
# - `País`
# - `Categoría_Producto`

# %% [markdown]
# ## 🔹 Paso 4: Crear visualizaciones efectivas
#
# - Construir Vista 1 (Overview Ejecutivo).
# - Construir Vista 2 (Análisis Detallado).
# - Asegurar claridad y coherencia visual.

# %% [markdown]
# ## 🔹 Paso 5: Narrativa con Modelo SCQA + mensaje asincrónico
#
# - Escribir la narrativa que
#   - reflejar lo que se observa en la **Vista General (Overview)**.
#   - explicar los hallazgos en la **Vista Detalle**.
# - Utilizar el modelo **SCQA (Situación, Complicación, Pregunta, Respuesta)**.
# - Mantener la narrativa clara, ejecutiva y breve.
# - Redactar un mensaje ejecutivo tipo Slack resumiendo el insight principal.

# %% [markdown]
# ### Narrativa del Dashboard (Modelo SCQA)
# Se describe de forma estructurada la historia completa del dashboard usando SCQA, incluyendo contexto, problemas detectados, preguntas de negocio y recomendaciones basadas en datos.

# %% [markdown]
# #### 🖥️ Vista General (Overview)
#
# **S (Situación):**
#
# Andes Retail Group opera en Perú, Chile y Colombia vendiendo productos en cuatro categorías principales: Electrónica, Ropa, Deportes y Hogar. El objetivo del dashboard es analizar el desempeño comercial durante los años 2024 y 2025 para entender la evolución de los ingresos y el comportamiento general del negocio.
#
# **C (Complicación):**
#
# Aunque el negocio ha generado ventas constantes, la información estaba distribuida en datos transaccionales sin una visualización clara que permitiera identificar tendencias, diferencias entre países o el impacto de las categorías de producto en los ingresos.
#
# **Q (Pregunta):**
#
# ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025 y qué factores del negocio están influyendo en su desempeño?
#
# **A (Respuesta):**
#
# El dashboard muestra la evolución de los ingresos a lo largo del tiempo, así como comparaciones entre países y categorías de producto. Los indicadores clave permiten identificar qué mercados y categorías contribuyen más al ingreso total, ofreciendo una visión rápida del estado actual del negocio.
#
# ---
#
# #### 🔎 Vista Detalle
#
# **S (Situación):**
#
# A partir de la vista general se identifican diferencias en el desempeño comercial entre países, segmentos de clientes y temporadas del año.
#
# **C (Complicación):**
#
# Estas variaciones sugieren que ciertos factores como la estacionalidad, el tipo de cliente o la región pueden estar influyendo en el comportamiento de los ingresos.
#
# **Q (Pregunta):**
#
# ¿Qué variables explican las variaciones en los ingresos y dónde existen oportunidades de mejora comercial?
#
# **A (Respuesta):**
#
# El análisis detallado permite comparar ingresos por estación, segmento de cliente y región, lo que facilita identificar patrones de consumo y mercados con mayor potencial. Esta información permite orientar estrategias comerciales hacia los segmentos y periodos con mayor impacto en el negocio.

# %% [markdown]
# ### Mensaje asincrónico para Slack (Modelo SCQA)
#
# Resume los insights más importantes en un mensaje breve.
# - Comunicar impacto en negocio y acciones recomendadas, como si lo enviaras a stakeholders por Slack.
# - Escribir un mensaje directo y conciso.

# %% [markdown]
# **📊 Actualización desempeño comercial**
#
# El dashboard muestra que el desempeño comercial entre 2024 y 2025 se mantiene impulsado principalmente por ciertas categorías de producto y mercados específicos. El análisis detallado indica que factores como la estacionalidad y el segmento de cliente influyen en las variaciones de ingresos, lo que sugiere oportunidades para enfocar estrategias comerciales en los segmentos y periodos con mayor potencial de crecimiento por país.
